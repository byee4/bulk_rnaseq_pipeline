# %% [markdown]
# # This notebook compares the outputs from our basic RNAseq pipeline and the "official ENCODE" version.

# %%
import pandas as pd
import numpy as np
import os
import glob

# %%
input_dir = '/home/bay001/projects/codebase/bulk_rnaseq_pipeline/tests/0.0.4/compare_pipeline_to_encode/inputs/'
output_dir = '/home/bay001/projects/codebase/bulk_rnaseq_pipeline/tests/0.0.4/compare_pipeline_to_encode/outputs/'

# %%
all_bams = sorted(glob.glob(os.path.join(input_dir, '*.bam')))
all_bams
# Out:
# ['/home/bay001/projects/codebase/bulk_rnaseq_pipeline/tests/0.0.4/compare_pipeline_to_encode/inputs/ENCFF040CTS.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted.bam',
#  '/home/bay001/projects/codebase/bulk_rnaseq_pipeline/tests/0.0.4/compare_pipeline_to_encode/inputs/ENCFF201PEI.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted.bam',
#  '/home/bay001/projects/codebase/bulk_rnaseq_pipeline/tests/0.0.4/compare_pipeline_to_encode/inputs/ENCFF511KFD.bam',
#  '/home/bay001/projects/codebase/bulk_rnaseq_pipeline/tests/0.0.4/compare_pipeline_to_encode/inputs/ENCFF880HKN.bam']

# %%
gencode = '/projects/ps-yeolab3/bay001/annotations/hg19/gencode_v19/gencode.v19.annotation.gtf'
counts = os.path.join(output_dir, 'counts.txt')

cmd = 'module load subreadfeaturecounts;featureCounts '
cmd += '-a {} -s 2 -o {} inputs/*.bam'.format(gencode, counts)

! $cmd
# Out:
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v1.5.3
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 4 BAM files                                      ||
# ||                           P inputs/ENCFF040CTS.fastqTr.sorted.STARUnma ... ||
# ||                           P inputs/ENCFF201PEI.fastqTr.sorted.STARUnma ... ||
# ||                           P inputs/ENCFF511KFD.bam                         ||
# ||                           P inputs/ENCFF880HKN.bam                         ||
# ||                                                                            ||
# ||             Output file : /home/bay001/projects/codebase/bulk_rnaseq_p ... ||
# ||                 Summary : /home/bay001/projects/codebase/bulk_rnaseq_p ... ||
# ||              Annotation : /projects/ps-yeolab3/bay001/annotations/hg19 ... ||
# ||      Dir for temp files : /home/bay001/projects/codebase/bulk_rnaseq_p ... ||
# ||                                                                            ||
# ||                 Threads : 1                                                ||
# ||                   Level : meta-feature level                               ||
# ||              Paired-end : no                                               ||
# ||         Strand specific : reversely stranded                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : not counted                                      ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file /projects/ps-yeolab3/bay001/annotations/hg19/genc ... ||
# ||    Features : 1196293                                                      ||
# ||    Meta-features : 57820                                                   ||
# ||    Chromosomes/contigs : 25                                                ||
# ||                                                                            ||
# || Process BAM file inputs/ENCFF040CTS.fastqTr.sorted.STARUnmapped.out.so ... ||
# ||    Paired-end reads are included.                                          ||
# ||    Assign reads to features...                                             ||
# ||    Total reads : 83504246                                                  ||
# ||    Successfully assigned reads : 27263390 (32.6%)                          ||
# ||    Running time : 2.41 minutes                                             ||
# ||                                                                            ||
# || Process BAM file inputs/ENCFF201PEI.fastqTr.sorted.STARUnmapped.out.so ... ||
# ||    Paired-end reads are included.                                          ||
# ||    Assign reads to features...                                             ||
# ||    Total reads : 96531504                                                  ||
# ||    Successfully assigned reads : 29563998 (30.6%)                          ||
# ||    Running time : 2.79 minutes                                             ||
# ||                                                                            ||
# || Process BAM file inputs/ENCFF511KFD.bam...                                 ||
# ||    Paired-end reads are included.                                          ||
# ||    Assign reads to features...                                             ||
# ||    Total reads : 85594236                                                  ||
# ||    Successfully assigned reads : 30462844 (35.6%)                          ||
# ||    Running time : 5.39 minutes                                             ||
# ||                                                                            ||
# || Process BAM file inputs/ENCFF880HKN.bam...                                 ||
# ||    Paired-end reads are included.                                          ||
# ||    Assign reads to features...                                             ||
# ||    Total reads : 99864052                                                  ||
# ||    Successfully assigned reads : 34293828 (34.3%)                          ||
# ||    Running time : 6.26 minutes                                             ||
# ||                                                                            ||
# ||                         Read assignment finished.                          ||
# ||                                                                            ||
# || Summary of counting results can be found in file "/home/bay001/projects/c  ||
# || odebase/bulk_rnaseq_pipeline/tests/0.0.4/compare_pipeline_to_encode/outpu  ||
# || ts/counts.txt"                                                             ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//

# %%
featurecounts_output = pd.read_csv(counts, sep='\t', skiprows=1, index_col=0)
featurecounts_output = featurecounts_output.iloc[:,5:]
featurecounts_output.head()
# Out:
#                    inputs/ENCFF040CTS.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted.bam  \
# Geneid
# ENSG00000223972.4                                                  1
# ENSG00000227232.4                                                 52
# ENSG00000243485.2                                                  1
# ENSG00000237613.2                                                  0
# ENSG00000268020.2                                                  0
#
#                    inputs/ENCFF201PEI.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted.bam  \
# Geneid
# ENSG00000223972.4                                                  0
# ENSG00000227232.4                                                118
# ENSG00000243485.2                                                  0
# ENSG00000237613.2                                                  0
# ENSG00000268020.2                                                  0
#
#                    inputs/ENCFF511KFD.bam  inputs/ENCFF880HKN.bam
# Geneid
# ENSG00000223972.4                       1                       0
# ENSG00000227232.4                      59                     132
# ENSG00000243485.2                       1                       0
# ENSG00000237613.2                       0                       0
# ENSG00000268020.2                       0                       0

# %%
featurecounts_output.corr()
# Out:
#                                                     inputs/ENCFF040CTS.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted.bam  \
# inputs/ENCFF040CTS.fastqTr.sorted.STARUnmapped....                                           1.000000
# inputs/ENCFF201PEI.fastqTr.sorted.STARUnmapped....                                           0.977703
# inputs/ENCFF511KFD.bam                                                                       0.995985
# inputs/ENCFF880HKN.bam                                                                       0.972401
#
#                                                     inputs/ENCFF201PEI.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted.bam  \
# inputs/ENCFF040CTS.fastqTr.sorted.STARUnmapped....                                           0.977703
# inputs/ENCFF201PEI.fastqTr.sorted.STARUnmapped....                                           1.000000
# inputs/ENCFF511KFD.bam                                                                       0.978242
# inputs/ENCFF880HKN.bam                                                                       0.996011
#
#                                                     inputs/ENCFF511KFD.bam  \
# inputs/ENCFF040CTS.fastqTr.sorted.STARUnmapped....                0.995985
# inputs/ENCFF201PEI.fastqTr.sorted.STARUnmapped....                0.978242
# inputs/ENCFF511KFD.bam                                            1.000000
# inputs/ENCFF880HKN.bam                                            0.980722
#
#                                                     inputs/ENCFF880HKN.bam
# inputs/ENCFF040CTS.fastqTr.sorted.STARUnmapped....                0.972401
# inputs/ENCFF201PEI.fastqTr.sorted.STARUnmapped....                0.996011
# inputs/ENCFF511KFD.bam                                            0.980722
# inputs/ENCFF880HKN.bam                                            1.000000
